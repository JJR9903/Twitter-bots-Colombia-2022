# %% [markdown]
# # Random Forest

# %%
import os
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ## Preprocesamiento

# %%
#Importar la base de datos
#os.chdir('/Users/santiagoherreragarcia/OneDrive - Universidad de los Andes/Semestre 2022-1/Machine Learning/Trabajo Final/Data')
os.chdir('/Users/JuanJose/Library/CloudStorage/OneDrive-UniversidaddelosAndes/Uniandes/8 Semestre/Machine Learning/Proyecto Final/Trabajo Final/Data')
marcas=pd.read_pickle('Y Botometer.pkl')
main_characteristics=pd.read_pickle('model_characteristics.pkl')
#Encontrar cuentas marcadas:
main_characteristics=main_characteristics.merge(marcas)
marcas=main_characteristics['bot']
main_characteristics.drop(columns=['bot'], inplace=True)

# %%
lisdir=os.listdir()

# %%
dfs=[]
for i in os.listdir():
    if 'user_model' in i:
        print(i)
        df=pd.read_pickle(i)
        if i=="user_model_juandi.pkl":
            df=df[['Author ID','ADJ%','ADP%', 'ADV%', 'AUX%', 'CCONJ%', 'DET%', 'INTJ%', 'PART%', 'PRON%','PROPN%', 'PUNCT%', 'SCONJ%', 'SYM%', 'VERB%', 'X%', 'SPACE%']]
            df=df.groupby(['Author ID'], as_index=False).mean()
        dfs.append(df)
for i in range(0, len(dfs)):
    print(i)
    dfs[i]['Author ID']=dfs[i]['Author ID'].astype(int).astype(str)
    main_characteristics=main_characteristics.merge(dfs[i], on='Author ID')
main_characteristics.drop(columns=['Author ID'], inplace=True)
# Out:
# user_model_texto.pkl
# user_model_analyze_descriptions.pkl
# user_model_juandi.pkl
# 0
# 1
# 2

# %%
#Split
x_train, x_test, y_train, y_test = train_test_split(main_characteristics, marcas, 
                                                    test_size=0.3, random_state=123)

# %%
#Sólo estandarizamos
standard=('standardize', StandardScaler())
scaler=Pipeline(steps=[standard])

# %%
#Aplicar estandarizacion
columns_scale=x_train.drop(columns=['Author Verified']).columns
x_train[columns_scale]=scaler.fit_transform(x_train[columns_scale])
x_test[columns_scale]=scaler.fit_transform(x_test[columns_scale])

# %% [markdown]
# ## Modelo

# %%
clf=RandomForestClassifier(random_state=123, n_jobs=-1)

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=123)

# %%
def model_cv(x,y,preprocessor,classifier,search_space):
    pipeline=Pipeline(
    steps=[('preprocesser', preprocessor), ('classifier', classifier)], 
    )
    clf=GridSearchCV(pipeline, search_space, scoring='accuracy', cv=3, verbose=4)
    clf.fit(x,y)
    
    return clf

# %%
yhat=clf.predict(x_test)

# %%
#Organizar los resultados por relevancia
Relevancia_PM=pd.DataFrame(clf.feature_importances_, index=x_train.columns).sort_values(by=0, ascending=False)
Relevancia_PM.to_latex(buf="Relevancia_PM.tex",index=False)
# Out:
#                                                   0
# TweetFeature Retweet                       0.130090
# TweetFeature Reply                         0.090616
# Tweet Retweets                             0.044378
# ADP%                                       0.032028
# Author Following                           0.031920
# Author Followers                           0.030429
# Tweet Favorites                            0.029596
# TweetFeature Quoted                        0.026807
# SPACE%                                     0.024718
# TweetFeature Distance Between Tweets (sd)  0.023560
# Author Tweets                              0.023286
# AUX%                                       0.022816
# Tweet Replies                              0.022245
# ADV%                                       0.022059
# TweetFeature First Date                    0.020663
# SCONJ%                                     0.019004
# PRON%                                      0.018938
# TweetFeature MentionRelevant UserName      0.018737
# usa emojis                                 0.018721
# TweetFeature Last Date                     0.017276
# cantidad emojis                            0.016952
# DET%                                       0.015814
# PUNCT%                                     0.015788
# TweetFeature Multimedia                    0.015649
# prop stopwords por usuario                 0.014819
# VERB%                                      0.014502
# SYM%                                       0.014483
# prop palabras politicas por usuario        0.014320
# CCONJ%                                     0.014076
# prop palabras relevantes por usuario       0.013928
# PROPN%                                     0.013706
# INTJ%                                      0.013368
# ADJ%                                       0.012025
# aggressive                                 0.011139
# emoji positivo                             0.010856
# positive                                   0.010586
# joy                                        0.010505
# negative                                   0.010021
# hateful                                    0.009920
# surprise                                   0.009390
# neutral                                    0.009369
# targeted                                   0.008162
# anger                                      0.007817
# fear                                       0.007433
# sadness                                    0.007172
# disgust                                    0.006906
# PART%                                      0.006434
# emoji negativo                             0.006327
# emoji neutral                              0.005834
# Tweet Quotes                               0.004078
# Author Verified                            0.000737
# X%                                         0.000000

# %%
print('Accuracy: '+str(accuracy_score(yhat, y_test)))
print('Precision: '+str(precision_score(yhat, y_test)))
print('Recall: '+str(recall_score(yhat, y_test)))
print('F1: '+str(f1_score(yhat, y_test)))
# Out:
# Accuracy: 0.9122448979591836
# Precision: 0.6217948717948718
# Recall: 0.5808383233532934
# F1: 0.6006191950464397

# %% [markdown]
# ## Hiperparámetros

# %% [markdown]
# Primero un random search:

# %%
# Number of trees in random forest
n_estimators = np.linspace(100, 3000, int((3000-100)/200) + 1, dtype=int)
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [1, 5, 10, 20, 50, 75, 100, 150, 200]
# Minimum number of samples required to split a node
# min_samples_split = [int(x) for x in np.linspace(start = 2, stop = 10, num = 9)]
min_samples_split = [1, 2, 5, 10, 15, 20, 30]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 3, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Criterion
criterion=['gini', 'entropy']
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'criterion': criterion}

# %%
rf_base = RandomForestClassifier(random_state=123)
rf_random = RandomizedSearchCV(estimator = rf_base,
                               param_distributions = random_grid,
                               n_iter = 30, cv = 5,
                               verbose=2,
                               random_state=42, n_jobs = 4)
rf_random.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END bootstrap=False, criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=  55.9s
# [CV] END bootstrap=False, criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=  56.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=  56.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=  56.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1135; total time=  10.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1135; total time=  10.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1135; total time=  10.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1135; total time=  11.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1135; total time=  11.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1135; total time=  22.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1135; total time=  20.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1135; total time=  21.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=  54.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1135; total time=  21.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1135; total time=  21.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=2585; total time= 1.3min
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=2585; total time= 1.3min
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=2585; total time= 1.3min
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=2585; total time= 1.3min
# [CV] END bootstrap=False, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1135; total time=  35.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1135; total time=  39.6s
# [CV] END bootstrap=False, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1135; total time=  37.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=2585; total time= 1.3min
# [CV] END bootstrap=False, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1135; total time=  39.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1135; total time=  39.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=2, min_samples_split=30, n_estimators=1964; total time=  39.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=2, min_samples_split=30, n_estimators=1964; total time=  38.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=2, min_samples_split=30, n_estimators=1964; total time=  38.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=2, min_samples_split=30, n_estimators=1964; total time=  38.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=928; total time=  18.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=2, min_samples_split=30, n_estimators=1964; total time=  38.0s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=928; total time=  17.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=928; total time=  17.9s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=928; total time=  17.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=928; total time=  17.6s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1757; total time=  54.7s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1757; total time=  59.6s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1757; total time=  57.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1757; total time=  57.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=2171; total time=  42.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=2171; total time=  40.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=2171; total time=  42.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1757; total time=  58.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1135; total time=  33.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1135; total time=  33.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=2171; total time=  47.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=2171; total time=  47.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1135; total time=  28.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1135; total time=  28.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=75, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=307; total time=   6.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1135; total time=  28.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=75, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=307; total time=   5.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=75, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=307; total time=   6.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=75, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=307; total time=   6.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=75, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=307; total time=   5.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=514; total time=  17.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=514; total time=  16.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=514; total time=  17.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=514; total time=  17.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=514; total time=  18.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1757; total time=  37.0s
# [CV] END bootstrap=True, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1757; total time=  36.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1757; total time=  36.9s
# [CV] END bootstrap=False, criterion=entropy, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=30, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=30, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=30, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=30, n_estimators=100; total time=   3.8s
# [CV] END bootstrap=False, criterion=entropy, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=30, n_estimators=100; total time=   3.9s
# [CV] END bootstrap=True, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1757; total time=  37.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=200, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1757; total time=  37.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1757; total time=  39.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1757; total time=  37.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=2, min_samples_split=30, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1757; total time=  37.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=2, min_samples_split=30, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=2, min_samples_split=30, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=2, min_samples_split=30, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=2, min_samples_split=30, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=721; total time=  10.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=721; total time=  10.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1757; total time=  36.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=721; total time=  10.7s
# [CV] END bootstrap=False, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=721; total time=  10.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1757; total time=  36.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=721; total time=  11.0s
# [CV] END bootstrap=True, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2585; total time=  11.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2585; total time=  11.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=1135; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=1135; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=1135; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=1135; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=1135; total time=   0.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2585; total time=  11.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2585; total time=  11.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=928; total time=   4.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=928; total time=   4.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=928; total time=   4.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2585; total time=  12.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=928; total time=   4.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=1, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=928; total time=   4.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=2585; total time= 1.5min
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=2585; total time= 1.5min
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=2585; total time= 1.5min
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=2585; total time= 1.5min
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1550; total time=  45.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1550; total time=  47.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1550; total time=  45.9s
# [CV] END bootstrap=False, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1757; total time=   8.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1757; total time=   8.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1757; total time=   8.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=75, max_features=auto, min_samples_leaf=1, min_samples_split=20, n_estimators=2585; total time= 1.3min
# [CV] END bootstrap=False, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1757; total time=   8.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=1, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1757; total time=   8.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1550; total time=  45.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=200, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1550; total time=  45.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=721; total time=  11.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=721; total time=  10.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=307; total time=   5.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=721; total time=  10.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=721; total time=  10.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=721; total time=  10.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=307; total time=   5.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=2378; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=307; total time=   5.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=2378; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=307; total time=   5.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=307; total time=   5.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=2378; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=2378; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=2378; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=150, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=721; total time=  16.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=721; total time=  16.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=721; total time=  16.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=721; total time=  16.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=721; total time=  13.1s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 450, in fit
#     trees = Parallel(
#   File "/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 937, in fit
#     super().fit(
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 250, in fit
#     raise ValueError(
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.90813432 0.885098   0.90900981 0.91571578 0.91834181 0.92154966
#  0.91659126 0.91542466 0.92096784 0.91834181 0.9171752  0.91542466
#  0.9174676  0.92067502 0.91834138 0.9171735  0.91892533 0.91630057
#  0.90959248 0.885098          nan 0.885098   0.91863336 0.91950799
#  0.885098   0.91571705 0.91717435        nan 0.91542636 0.91717435]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=123),
#                    n_iter=30, n_jobs=4,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [1, 5, 10, 20, 50, 75, 100,
#                                                       150, 200],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 3, 4],
#                                         'min_samples_split': [1, 2, 5, 10, 15,
#                                                               20, 30],
#                                         'n_estimators': array([ 100,  307,  514,  721,  928, 1135, 1342, 1550, 1757, 1964, 2171,
#        2378, 2585, 2792, 3000])},
#                    random_state=42, verbose=2)

# %%
random_params=rf_random.best_params_

# %% [markdown]
# Luego intentamos con un grid search, una vez tengamos mejores candidatos

# %%
param_grid = {
    'n_estimators': np.linspace(random_params['n_estimators']-10, random_params['n_estimators']+10, 2, dtype = int),
    'max_depth': [abs(random_params['max_depth']-2),
                  abs(random_params['max_depth']-1),random_params['max_depth'], random_params['max_depth']+1,
                 random_params['max_depth']+2],
    'min_samples_split': [abs(random_params['min_samples_split']-1),random_params['min_samples_split'],
                         random_params['min_samples_split']+1],
    'min_samples_leaf': [abs(random_params['min_samples_leaf']-1), random_params['min_samples_leaf'],
                        random_params['min_samples_leaf']+1]
}
rf_base = RandomForestClassifier(random_state=123, criterion='gini',bootstrap=True)
rf_grid = GridSearchCV(estimator = rf_base,
                               param_grid = param_grid,
                               cv = 5,
                               verbose=2,
                               n_jobs = 4)
rf_grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  21.9s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  22.7s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  23.7s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  22.1s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  21.7s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  22.4s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  23.5s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  22.9s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  22.7s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  21.3s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  23.1s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  23.6s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  23.8s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  24.2s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.2s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  22.5s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  23.4s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  23.9s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  23.6s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  25.1s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  24.1s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  24.1s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  23.9s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  23.1s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.3s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  24.2s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.5s
# [CV] END max_depth=148, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.3s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  24.8s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.3s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.2s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.6s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.5s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  24.5s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  23.3s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  24.2s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  24.4s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  24.6s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.8s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.1s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.7s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  23.0s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  24.8s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  24.3s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  24.5s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  24.2s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  24.6s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  22.7s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  24.7s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  25.1s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  24.9s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  26.0s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  23.6s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  24.4s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  24.6s
# [CV] END max_depth=148, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  24.7s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.8s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  24.8s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  23.8s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  23.9s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  24.2s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.5s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  23.3s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  24.6s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  24.6s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  24.9s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  23.4s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  25.0s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  25.4s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  25.3s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  26.4s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  22.1s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  22.8s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  23.0s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  22.4s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  21.6s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  20.3s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  20.9s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  21.1s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.1s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  21.8s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.3s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  22.7s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  22.4s
# [CV] END max_depth=148, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  22.3s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  24.4s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  22.5s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  23.4s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  23.7s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  23.5s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  25.3s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  25.6s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  26.9s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  27.3s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  26.8s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  26.8s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  24.8s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  25.6s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  25.8s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  26.7s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  27.9s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.7s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  26.2s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  23.1s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  22.8s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  23.3s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  21.4s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  24.7s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  25.2s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  25.1s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  26.5s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.0s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.3s
# [CV] END max_depth=149, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.5s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  25.1s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.5s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  24.3s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  24.0s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  22.4s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  23.2s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  21.5s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  22.4s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  22.5s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  22.3s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.4s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  21.0s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  21.8s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.2s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.3s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  23.2s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  21.4s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  22.1s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  22.2s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  21.9s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  22.6s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  21.2s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  21.9s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  22.1s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  24.4s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  23.0s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  23.9s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  22.8s
# [CV] END max_depth=149, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  22.3s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.0s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  20.2s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.2s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  23.1s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  24.1s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.5s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.6s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.8s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.7s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  22.3s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  20.9s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  21.6s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  21.8s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  21.5s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  21.0s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  22.5s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  21.6s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  22.0s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  22.2s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.4s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  21.2s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.6s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.6s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.5s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.5s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  22.8s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.9s
# [CV] END max_depth=149, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  24.9s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  23.3s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  24.1s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  24.4s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  24.2s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  23.9s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  25.9s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  24.9s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  25.6s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  24.8s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  25.3s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  23.2s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  24.1s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  24.6s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  24.5s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.8s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  23.6s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.0s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.4s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.1s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  26.3s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  24.6s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  26.0s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  26.2s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  25.6s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  26.9s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  24.4s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.2s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  24.9s
# [CV] END max_depth=150, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  24.4s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  24.0s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  22.2s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.2s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  24.5s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  24.4s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  25.8s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  23.7s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  24.0s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  23.3s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.8s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.8s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.5s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.8s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.9s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  23.3s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  24.9s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  24.0s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  25.3s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  24.7s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  25.0s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  23.4s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  22.1s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  22.6s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  22.4s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  23.5s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  22.6s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  23.4s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=150, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  23.9s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  23.5s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.0s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.7s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.6s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  21.6s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  21.0s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.8s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  21.8s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  21.9s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  21.9s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  22.3s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  20.8s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  22.5s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  23.1s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  24.1s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  23.1s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  24.3s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  24.6s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  24.3s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  24.1s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.0s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.8s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  22.2s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.1s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  22.3s
# [CV] END max_depth=150, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  22.0s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  24.1s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  22.2s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  23.4s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  24.0s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  22.0s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  22.4s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  22.7s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  22.9s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  23.6s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  22.1s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  23.5s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  24.8s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  23.0s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  24.0s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  24.3s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  24.3s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  24.7s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  22.5s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  22.7s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  22.6s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  22.3s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  24.2s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  22.5s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  24.2s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  24.4s
# [CV] END max_depth=151, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.3s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  21.6s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  22.5s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.2s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  24.2s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  22.5s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  23.3s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  23.7s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  24.0s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.6s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.2s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.7s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  24.2s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  25.0s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  27.2s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  27.6s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  27.3s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  25.9s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  23.3s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  23.9s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  24.7s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  24.1s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  24.3s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  25.9s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  24.2s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  24.4s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  23.5s
# [CV] END max_depth=151, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  21.9s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  23.1s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.8s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  23.9s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.1s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  23.9s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  24.0s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  23.9s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  21.8s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  22.5s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  22.5s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  22.2s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  23.2s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  24.9s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  24.6s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  27.2s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  26.9s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  26.9s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  25.0s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  23.4s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.4s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.3s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.7s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.0s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  23.8s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  24.0s
# [CV] END max_depth=151, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  24.0s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  25.4s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  23.7s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  24.4s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  24.8s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1125; total time=  25.6s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  25.6s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  27.5s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  25.8s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  25.2s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=9, n_estimators=1145; total time=  25.0s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  25.6s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  23.7s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  23.9s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  24.5s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1125; total time=  24.2s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.9s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  24.3s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.0s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.5s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=10, n_estimators=1145; total time=  25.2s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  26.7s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  25.8s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  26.9s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  26.8s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1125; total time=  25.5s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  23.3s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.8s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  24.5s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.3s
# [CV] END max_depth=152, min_samples_leaf=1, min_samples_split=11, n_estimators=1145; total time=  25.3s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  24.8s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.5s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.8s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1125; total time=  23.9s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  25.1s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  23.5s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  24.4s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  24.6s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=9, n_estimators=1145; total time=  24.3s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.8s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  22.8s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  23.5s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  24.0s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1125; total time=  24.2s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  23.2s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  24.9s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  23.7s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  23.3s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=10, n_estimators=1145; total time=  23.1s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  23.4s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  21.6s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  22.9s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  23.2s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  23.9s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  21.7s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  22.4s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  22.8s
# [CV] END max_depth=152, min_samples_leaf=2, min_samples_split=11, n_estimators=1145; total time=  22.9s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  23.1s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  21.4s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.2s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.1s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1125; total time=  22.5s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  23.9s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.4s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  23.2s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.5s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=9, n_estimators=1145; total time=  22.7s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  23.0s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  21.5s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  22.8s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  23.1s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1125; total time=  23.1s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  24.1s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  21.8s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  22.2s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  22.4s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=10, n_estimators=1145; total time=  22.1s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  22.2s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  21.0s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  21.7s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  21.8s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1125; total time=  21.9s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  22.9s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  21.5s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  21.6s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  19.4s
# [CV] END max_depth=152, min_samples_leaf=3, min_samples_split=11, n_estimators=1145; total time=  17.0s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=123), n_jobs=4,
#              param_grid={'max_depth': [148, 149, 150, 151, 152],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [9, 10, 11],
#                          'n_estimators': array([1125, 1145])},
#              verbose=2)

# %%
rf_grid.best_params_
# Out:
# {'max_depth': 148,
#  'min_samples_leaf': 1,
#  'min_samples_split': 10,
#  'n_estimators': 1125}

# %%
clf_hyperparams=RandomForestClassifier(random_state=123, n_jobs=-1,n_estimators=1125,min_samples_split=10,min_samples_leaf=1,max_depth=148)

# %%
clf_hyperparams.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=148, min_samples_split=10, n_estimators=1125,
#                        n_jobs=-1, random_state=123)

# %%
yhat_hiper=clf_hyperparams.predict(x_test)

# %%
pd.DataFrame(clf_hyperparams.feature_importances_, index=x_train.columns).sort_values(by=0, ascending=False)
# Out:
#                                                   0
# TweetFeature Retweet                       0.130253
# TweetFeature Reply                         0.107741
# Tweet Retweets                             0.047283
# Tweet Favorites                            0.045829
# TweetFeature Quoted                        0.035757
# ADP%                                       0.033054
# Author Following                           0.031568
# Author Followers                           0.030153
# SPACE%                                     0.026081
# Author Tweets                              0.024502
# ADV%                                       0.023764
# TweetFeature Distance Between Tweets (sd)  0.022503
# TweetFeature MentionRelevant UserName      0.022260
# TweetFeature First Date                    0.021526
# Tweet Replies                              0.021180
# cantidad emojis                            0.019844
# usa emojis                                 0.019369
# PRON%                                      0.018321
# AUX%                                       0.018052
# SCONJ%                                     0.016609
# TweetFeature Last Date                     0.014943
# DET%                                       0.014678
# TweetFeature Multimedia                    0.014500
# PUNCT%                                     0.014462
# SYM%                                       0.013129
# VERB%                                      0.012774
# prop stopwords por usuario                 0.012380
# prop palabras relevantes por usuario       0.012055
# prop palabras politicas por usuario        0.011908
# CCONJ%                                     0.011858
# PROPN%                                     0.011322
# INTJ%                                      0.010386
# ADJ%                                       0.010323
# emoji positivo                             0.009405
# joy                                        0.008737
# neutral                                    0.008640
# aggressive                                 0.008570
# negative                                   0.008551
# hateful                                    0.008454
# positive                                   0.007852
# surprise                                   0.007671
# targeted                                   0.007174
# disgust                                    0.006484
# anger                                      0.006257
# sadness                                    0.006186
# fear                                       0.006061
# emoji negativo                             0.004965
# PART%                                      0.004839
# emoji neutral                              0.004285
# Tweet Quotes                               0.004214
# Author Verified                            0.001284
# X%                                         0.000002

# %%
print('Accuracy: '+str(accuracy_score(yhat_hiper, y_test)))
print('Precision: '+str(precision_score(yhat_hiper, y_test)))
print('Recall: '+str(recall_score(yhat_hiper, y_test)))
print('F1: '+str(f1_score(yhat_hiper, y_test)))
# Out:
# Accuracy: 0.9163265306122449
# Precision: 0.6153846153846154
# Recall: 0.6037735849056604
# F1: 0.6095238095238096
